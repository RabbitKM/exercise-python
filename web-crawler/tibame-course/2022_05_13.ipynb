# %%
#JSON-圖片
import requests
import io
import json
import codecs

fn = 0
for p in range(1,6,1):
  req = requests.get(
      'https://udn.com/api/more',
      headers={
          'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/101.0.4951.54 Safari/537.36',
          'Referer': 'https://data.gov.tw/datasets/search?p=1&size=10&rct=285&rafft=6410',
          'Cookie': '_ga=GA1.3.253445803.1652016416; auth.strategy=local; _gid=GA1.3.1823959815.1652333736',
      },
      params={
          'page': p,
          'id': '',
          'channelId': '1',
          'cate_id': '0',
          'type': 'breaknews',
          'totalRecNo': '11260',

      },
      data={},
  )
  ret = json.loads(req.text)

  for dd in ret['lists']:
    req2 = requests.get(dd['url'])
    fn += 1
    with codecs.open('news_image/' + str(fn) + '.jpg', 'wb') as f:
      f.write(req2.content)
    print(dd['time']['date'],dd['title'])
# Out:
# 2022-07-12 18:16 英國可能迎來第三位女首相？保守黨基層青睞摩丹特出線
# 2022-07-12 18:13 7月外匯投資術 什麼貨幣「攬牢牢」才能趨吉避凶？
# 2022-07-12 18:11 台亞來頭不小 有這家國際大廠撐腰攻第三代半導體
# 2022-07-12 18:11 台大校長9名候選人正式名單出爐 10月8日前選出新校長
# 2022-07-12 18:11 新加坡羽賽／麟洋配過頭關 戴資穎13日早上9點台灣內戰
# 2022-07-12 18:10 近零碳建築啟動／加速推動老舊建物能效改善 學者開三藥方
# 2022-07-12 18:10 習近平提兩岸青年交流  陸委會：是陸方先中斷陸生
# 2022-07-12 18:10 NBA／自曝沒有考慮轉隊 唐西奇：想為獨行俠奪下總冠軍
# 2022-07-12 18:09 近零碳建築啟動／跟時間賽跑 全台410萬老舊建物拚30年翻新
# 2022-07-12 18:06 張善政自認不會政治話術 預告2天後出關見鄉親
# 2022-07-12 18:04 早餐店2塊起司蛋餅拉出4根捲毛 網友齊崩潰：好噁心
# 2022-07-12 18:04 疫情趨緩航運復甦 桃園機場6月客運量年增191%
# 2022-07-12 18:03 基隆海面出現疑從雲嘉南北漂的蚵棚 蚵串早被採收一空
# 2022-07-12 18:02 T1聯盟／海神補進兩大物放眼連霸 太陽帶回台中孩子
# 2022-07-12 18:01 滬倡議做好14天食品和醫藥儲備  當事居委會：友情提醒
# 2022-07-12 17:58 不挺阻貶日圓！葉倫：干預匯市只在罕見情況下才有必要
# 2022-07-12 17:58 美國零負評「優植肉」家樂福上架 蔬食調理包新選
# 2022-07-12 17:56 花園與武士魂：安倍晉三死後的日本「和平癡呆」？
# 2022-07-12 17:56 中職／前兩輪等不到池恩齊 小黑媽媽差點出門拐氣
# 2022-07-12 17:52 斗六公所開公聽會挺民意 提5大訴求堅決反對蓋焚化爐
# 2022-07-12 17:52 越野騎士汐止新山夢湖林道身亡 解剖顱內出血
# 2022-07-12 17:51 羽球／讚戴資穎打法靈活、全方位 前中國教練：能抗衡者不多
# ...

# %%
# !zip -r a.zip news_image
# Out:
#   adding: news_image/ (stored 0%)
#   adding: news_image/7.jpg (deflated 0%)
#   adding: news_image/14.jpg (deflated 1%)
#   adding: news_image/50.jpg (deflated 0%)
#   adding: news_image/97.jpg (deflated 0%)
#   adding: news_image/77.jpg (deflated 0%)
#   adding: news_image/55.jpg (deflated 5%)
#   adding: news_image/31.jpg (deflated 0%)
#   adding: news_image/39.jpg (deflated 0%)
#   adding: news_image/84.jpg (deflated 0%)
#   adding: news_image/88.jpg (deflated 0%)
#   adding: news_image/37.jpg (deflated 0%)
#   adding: news_image/56.jpg (deflated 0%)
#   adding: news_image/5.jpg (deflated 0%)
#   adding: news_image/65.jpg (deflated 0%)
#   adding: news_image/10.jpg (deflated 2%)
#   adding: news_image/8.jpg (deflated 0%)
#   adding: news_image/29.jpg (deflated 0%)
#   adding: news_image/24.jpg (deflated 2%)
#   adding: news_image/80.jpg (deflated 1%)
#   adding: news_image/42.jpg (deflated 1%)
#   adding: news_image/98.jpg (deflated 0%)
# ...

# %%
#JSON-圖片
import requests
import io
import json
import codecs

fn = 0
for p in range(1,6,1):
  req = requests.get(
      'https://xapi.pcone.com.tw/search/commodities',
      headers={
          'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/101.0.4951.54 Safari/537.36',
          'Referer': 'https://data.gov.tw/datasets/search?p=1&size=10&rct=285&rafft=6410',
          'Cookie': '_ga=GA1.3.253445803.1652016416; auth.strategy=local; _gid=GA1.3.1823959815.1652333736',
      },
      params={
          'site': 'pcone',
          'direction': 'asc',
          'page': p,
          'q': 'apple',
          'sorting': 'default',
          'device': 'desktop',
          'aid': 'null',
      },
      data={},
  )
  ret = json.loads(req.text)

  for dd in ret['data']['commodities']:
    req2 = requests.get(dd['images']['small'],headers={
       'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:100.0) Gecko/20100101 Firefox/100.0',
       'Referer': 'https://www.pcone.com.tw/search?q=apple',
       'Cookie': 'sid2_raw=gs_4; sids[1652405961]=gs_4; device_hash=627db6c963173ea52d2d9b4d; x_device_hash=627db6c963173ea52d2d9b4e; dsid=627db6c963173ea52d2d9b4f; _gcl_aw=GCL.1652405961.EAIaIQobChMIoNra76vb9wIVoNVMAh1TpQwNEAAYASAAEgJXafD_BwE; _gcl_au=1.1.1688278007.1652405961; _ga=GA1.3.329817456.1652405962; _gid=GA1.3.1091925313.1652405962; _gac_UA-76339624-3=1.1652405962.EAIaIQobChMIoNra76vb9wIVoNVMAh1TpQwNEAAYASAAEgJXafD_BwE; _fbp=fb.2.1652405962807.2111640024; cto_bundle=2905218wdnNwN1hYa2hJRUZoSVZVQUQ5R2h4dE04RWJsMXMybnhzYjk4ZUo5RE90YktaSjBycWZnVnlPQW1WZU4lMkY3VEI2UXVHT05oaThFeGRQcTBxdWVSUWthcmVaZ2RQZXRScFFTTWJaOGdRMzElMkJIS3ZlJTJGdEF6elZLSXMlMkZWZzNndng1ZmdVNVN0cEF6WUw5cFZlM0xZMXNxUSUzRCUzRA; 1800=1; announcementDate=13; _gat_UA-76339624-3=1; _gat=1'
    })
    fn += 1
    with codecs.open('pcone_image/' + str(fn) + '.jpg', 'wb') as f:
      f.write(req2.content)
    print(dd['name'],dd['price'])
# Out:
# 【APPLE蘋果】Air Tag(A2187) 防潑水/失物尋找/精確尋找指引 3196
# 【Apple蘋果】iPhone 13(6.1吋) 星光色、午夜色、藍色 23980
# 【APPLE】HomePod mini 無線喇叭/藍芽喇叭/藍芽音箱/廣播 2795
# Apple AirPods Pro Magsafe版 藍牙耳機 保固一年  5990
# Apple Watch Series 6 智慧手錶 42796
# 【Apple】Apple Pencil 2 觸控筆 NG新品 福利品 3050
# 【Apple】Watch Series SE福利機(黑/白/玫瑰金) 運動手環 31596
# 【APPLE】IPAD Air 4 2020版 送保護貼 福利品 顏色隨機 14500
# 【Apple】iPhone SE 3代(2022)128G 4.7吋 智慧型手機 15500
# 【Apple】原廠USB-C2m連接線(適用iphone及ipad) 充電線 16000
# Apple iPhone 11 Pro 64GB  贈四好禮 14450
# 【APPLE】IPAD PRO 12.9 2020版 第四代 福利品  27500
# APPLE iPad mini 2 32G WIFI版 7.9吋 平板 4690
# 【Apple 蘋果】USB-C 對 Lightning 連接線 (1公尺) 7800
# 【Apple】AirPods 2有線充電版藍牙耳機 3850
# 【Apple】iPhone SE 3 64G 128G 256G 贈空壓殼 13900
# 【Apple】iPad mini 6 平板8.3吋 64G 256G Wi-Fi 15200
# 【Apple】Watch Series 4 福利品 運動手環/健康手環 26396
# Apple iPhone 11 64GB 手機 贈四好禮 福利品 11488
# 【Apple蘋果】iPhone 13現貨 A2633 6.1吋手機/智慧型手機 27288
# 【DOHO】Apple IPhone6 6s 6sPlus 9H滿版鋼化玻璃 1963
# iPhone充電傳輸線 (A-1m) 蘋果充電線 電源線 APPLE電源線 1520
# ...

# %%
# !zip -r b.zip pcone_image
# Out:
#   adding: pcone_image/ (stored 0%)
#   adding: pcone_image/109.jpg (deflated 61%)
#   adding: pcone_image/7.jpg (deflated 63%)
#   adding: pcone_image/14.jpg (deflated 63%)
#   adding: pcone_image/118.jpg (deflated 61%)
#   adding: pcone_image/122.jpg (deflated 61%)
#   adding: pcone_image/50.jpg (deflated 63%)
#   adding: pcone_image/140.jpg (deflated 61%)
#   adding: pcone_image/97.jpg (deflated 61%)
#   adding: pcone_image/77.jpg (deflated 63%)
#   adding: pcone_image/55.jpg (deflated 63%)
#   adding: pcone_image/132.jpg (deflated 61%)
#   adding: pcone_image/114.jpg (deflated 63%)
#   adding: pcone_image/31.jpg (deflated 63%)
#   adding: pcone_image/39.jpg (deflated 63%)
#   adding: pcone_image/84.jpg (deflated 63%)
#   adding: pcone_image/88.jpg (deflated 61%)
#   adding: pcone_image/37.jpg (deflated 63%)
#   adding: pcone_image/56.jpg (deflated 63%)
#   adding: pcone_image/5.jpg (deflated 63%)
#   adding: pcone_image/65.jpg (deflated 63%)
# ...

# %%
# HTML
import requests
import io
from bs4 import BeautifulSoup

r1 = requests.get(
    'https://www.cdc.gov.tw/Bulletin/List/MmgtpeidAR5Ooai4-fgHzQ',
    headers={
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/101.0.4951.54 Safari/537.36',
        'Referer': 'https://data.gov.tw/datasets/search?p=1&size=10&rct=285&rafft=6410',
        'Cookie': '_ga=GA1.3.253445803.1652016416; auth.strategy=local; _gid=GA1.3.1823959815.1652333736',
    },
)
p1 = BeautifulSoup(r1.text, 'html.parser')
ret = p1.find_all(
    'p',{
    'class': 'JQdotdotdot'
    }
)
for dd in ret:
  print(dd.text)
  # dd.attrs['title']
# Out:
# 開設學齡前兒童就醫綠色通道，優先照顧兒童
# 有關網傳「防護面罩預算63.9億，快篩預算僅5264萬」之澄清說明
# 自5月14日起，新增居家隔離、自主防疫及居家檢疫3類對象快篩陽性評估管道
# 新增65,011例COVID-19確定病例，分別為64,972例本土及39例境外移入
# 5月13日起開放符合口服抗病毒藥物用藥條件之COVID-19確診者，可由親友代為看診以評估使用口服抗病毒藥物
# 新增65,446例COVID-19確定病例，分別為65,385例本土及61例境外移入
# 新增57,216例COVID-19確定病例，分別為57,188例本土及28例境外移入
# 新增50,828例COVID-19確定病例，分別為50,780例本土及48例境外移入
# 「數位新冠病毒健康證明」系統版本更新，增列顯示身分證字號之需求
# 新增40,304例COVID-19確定病例，分別為40,263例本土及41例境外移入

# %%
# HTML
import requests
import io
from bs4 import BeautifulSoup

for p in range(1,4,1):
  r1 = requests.get(
      'https://www.cdc.gov.tw/Bulletin/List/MmgtpeidAR5Ooai4-fgHzQ',
      headers={
          'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/101.0.4951.54 Safari/537.36',
          'Referer': 'https://data.gov.tw/datasets/search?p=1&size=10&rct=285&rafft=6410',
          'Cookie': '_ga=GA1.3.253445803.1652016416; auth.strategy=local; _gid=GA1.3.1823959815.1652333736',
      },
      params={
          'page': p
      }
  )
  p1 = BeautifulSoup(r1.text, 'html.parser')
  ret = p1.find_all(
      'div',{
      'class': 'content-boxes-v3'
      }
  )

  for dd in ret:
    print(dd.find('a').attrs['title'])
# Out:
# 開設學齡前兒童就醫綠色通道，優先照顧兒童
# 有關網傳「防護面罩預算63.9億，快篩預算僅5264萬」之澄清說明
# 自5月14日起，新增居家隔離、自主防疫及居家檢疫3類對象快篩陽性評估管道
# 新增65,011例COVID-19確定病例，分別為64,972例本土及39例境外移入
# 5月13日起開放符合口服抗病毒藥物用藥條件之COVID-19確診者，可由親友代為看診以評估使用口服抗病毒藥物
# 新增65,446例COVID-19確定病例，分別為65,385例本土及61例境外移入
# 新增57,216例COVID-19確定病例，分別為57,188例本土及28例境外移入
# 新增50,828例COVID-19確定病例，分別為50,780例本土及48例境外移入
# 「數位新冠病毒健康證明」系統版本更新，增列顯示身分證字號之需求
# 新增40,304例COVID-19確定病例，分別為40,263例本土及41例境外移入
# 今年第一批採購Pfizer-BioNTech成人劑型疫苗185.796萬劑於今日上午抵臺
# 新增44,361例COVID-19確定病例，分別為44,294例本土及67例境外移入
# 5月8日零時起，調整密切接觸者匡列以同住親友為原則，職場及學校採自主應變；取消居家隔離者電子圍籬措施
# 新增46,536例COVID-19確定病例，分別為46,377例本土及159例境外移入
# 今(2022)年第八批採購Moderna疫苗125.09萬劑將於今(7)日下午抵臺
# 即日起增加公費PCR核酸檢驗採檢服務診所，籲請抗原快篩陽性或有症狀民眾多加利用
# 新增36,213例COVID-19確定病例，分別為36,168例本土及45例境外移入
# 指揮中心緊急增備快篩試劑，廠商須符合3資格並於投標後查驗相關文件
# 指揮中心修訂病例定義，居家隔離/檢疫對象如快篩陽性，經醫事人員確認即為確診
# 新增30,106例COVID-19確定病例，分別為30,035例本土及71例境外移入
# 指揮中心重申，政府徵用快篩試劑均依法執行，絕無圖利特定代理商
# 「Taiwan V-Watch」兒童及青少年版上線，鼓勵家長代未成年子女加入並填寫COVID-19疫苗接種後健康回報
# 今年第七批採購Moderna疫苗111.55萬劑將於今(4)日下午抵臺
# ...

# %%
# HTML
import requests
import io
from bs4 import BeautifulSoup
import codecs

fn = 0
for p in range(1,4,1):
  r1 = requests.get(
      'https://www.cdc.gov.tw/Bulletin/List/MmgtpeidAR5Ooai4-fgHzQ',
      headers={
          'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/101.0.4951.54 Safari/537.36',
          'Referer': 'https://data.gov.tw/datasets/search?p=1&size=10&rct=285&rafft=6410',
          'Cookie': '_ga=GA1.3.253445803.1652016416; auth.strategy=local; _gid=GA1.3.1823959815.1652333736',
      },
      params={
          'page': p
      }
  )
  p1 = BeautifulSoup(r1.text, 'html.parser')
  ret = p1.find_all('div',{'class': 'content-boxes-v3'})

  for dd in ret:

    r2 = requests.get(
    'https://www.cdc.gov.tw'+dd.find('a').attrs['href'],
    headers={
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/101.0.4951.54 Safari/537.36',
        'Referer': 'https://data.gov.tw/datasets/search?p=1&size=10&rct=285&rafft=6410',
        'Cookie': '_ga=GA1.3.253445803.1652016416; auth.strategy=local; _gid=GA1.3.1823959815.1652333736',
      },
    )
    p2 = BeautifulSoup(r2.text, 'html.parser')
    fn += 1
    with codecs.open('cdc/'+str(fn)+'.txt', 'w', 'utf-8') as f:
      f.write(dd.find('a').attrs['title']+'\r\n\r\n')
      ret2 = p2.find('div',{'class':'news-v3-in'})
      for dd2 in ret2.find_all('div'):
        if 'class' not in dd2.attrs:
          f.write(dd2.text)
    # print(dd.find('a').attrs['href'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-96ef92861e37> in <module>()
#      28         'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/101.0.4951.54 Safari/537.36',
# ...

# %%
# !zip -r c.zip cdc
# Out:
#   adding: cdc/ (stored 0%)
#   adding: cdc/6.txt (deflated 51%)
#   adding: cdc/21.txt (deflated 36%)
#   adding: cdc/17.txt (deflated 51%)
#   adding: cdc/13.txt (deflated 47%)
#   adding: cdc/1.txt (deflated 45%)
#   adding: cdc/18.txt (deflated 44%)
#   adding: cdc/7.txt (deflated 50%)
#   adding: cdc/26.txt (deflated 45%)
#   adding: cdc/16.txt (deflated 46%)
#   adding: cdc/11.txt (deflated 40%)
#   adding: cdc/23.txt (deflated 39%)
#   adding: cdc/22.txt (deflated 45%)
#   adding: cdc/14.txt (deflated 50%)
#   adding: cdc/24.txt (deflated 51%)
#   adding: cdc/19.txt (deflated 49%)
#   adding: cdc/20.txt (deflated 51%)
#   adding: cdc/12.txt (deflated 50%)
#   adding: cdc/4.txt (deflated 51%)
#   adding: cdc/28.txt (deflated 51%)
#   adding: cdc/9.txt (deflated 39%)
#   adding: cdc/15.txt (deflated 40%)
#   adding: cdc/3.txt (deflated 53%)
#   adding: cdc/27.txt (deflated 38%)
#   adding: cdc/5.txt (deflated 47%)
#   adding: cdc/25.txt (deflated 51%)
# ...

# %%
# HTML
import requests
import io
from bs4 import BeautifulSoup
import codecs

fn = 0
for p in range(1,4,1):
  r1 = requests.get(
      'https://news.ebc.net.tw/realtime',
      headers={
          'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/101.0.4951.54 Safari/537.36',
          'Referer': 'https://data.gov.tw/datasets/search?p=1&size=10&rct=285&rafft=6410',
          'Cookie': '_ga=GA1.3.253445803.1652016416; auth.strategy=local; _gid=GA1.3.1823959815.1652333736',
      },
      params={
          'page': p
      }
  )
  p1 = BeautifulSoup(r1.text, 'html.parser')
  # print(p1)
  ret = p1.find_all('span',{'class': 'title'})
  print(ret)

  for dd in ret:
    if dd.text != '':
      print(
          dd.parent.find('span',{'class': 'small-gray-text'}).text,
          dd.text
      )
# Out:
# [<span class="title">姊姊年齡猜不透！原來姊弟戀這樣談超恩愛！</span>, <span class="title">同事快篩陽！隔天辦公室大改造 他傻眼：這是類方艙？</span>, <span class="title">科技公司徵「工程師兼外送」月薪80K他心動 網見細節笑了</span>, <span class="title">通膨+升息房租漲不停！ 租金指數創新高 南部年漲1.73%最辛苦</span>, <span class="title">買20坪小宅該「加140萬買車位」？網分析齊勸：當然要買</span>, <span class="title">記者問一問題！陳時中聽完罕動怒 3連發回擊：為什麼？</span>, <span class="title">超商取貨付款有漏洞 男低價條碼貼高價品上詐騙</span>, <span class="title">全聯擴大快篩試劑門市 北北基桃以外門市下午開賣</span>, <span class="title">信守承諾！愛妻治病「今成骨灰」 尪徒步7小時帶她回家</span>, <span class="title">他驚覺房仲推薦的「全在高架橋旁」！網疑：想割韭菜？</span>, <span class="title">快訊／第四劑疫苗開打 優先接種族群曝光</span>, <span class="title">親友代看診領藥上路！ 須備妥「健保卡、確診證明」</span>, <span class="title">公立醫療體系設就醫綠色通道 強化學齡前兒童照護</span>, <span class="title">「限三類」快篩陽性即確診 醫籲：盛行率高應全面開放</span>, <span class="title">緊鄰信義區房價差1倍！北市這區捷運周邊 還有3字頭</span>, <span class="title">家長搶買唾液快篩 醫：敏感度低、有3成偽陰性</span>, <span class="title">美式賣場品管出包？ 民眾疑似買到用過的帳篷 賣場：調查中</span>, <span class="title">黑洞新發現！銀河系中心超大質量黑洞影像曝光</span>, <span class="title">一表揭殘酷現實 房貸期少1
# ...

# %%
# HTML
import requests
import io
from bs4 import BeautifulSoup
import codecs


r1 = requests.get(
    'http://teaching.bo-yuan.net/',
    headers={
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/101.0.4951.54 Safari/537.36',
        'Referer': 'https://data.gov.tw/datasets/search?p=1&size=10&rct=285&rafft=6410',
        'Cookie': 'PHPSESSID=3j077r0jm9ib4jf1ocs6265f8s',
    },
)


with codecs.open('2.html', 'w', 'utf-8') as f:
  f.write(r1.text)

# %%
import requests
import io
from bs4 import BeautifulSoup
import codecs

r1 = requests.post(
    'http://teaching.bo-yuan.net/',
    headers={
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/101.0.4951.54 Safari/537.36',
        'Referer': 'https://data.gov.tw/datasets/search?p=1&size=10&rct=285&rafft=6410',
        'Cookie': 'PHPSESSID=3j077r0jm9ib4jf1ocs6265f8s',
    },
    params={
        'ex': 'login'
    },
    data={
        'ex[class]': '626eaa0ec3e72',
        'ex[username]': '09陳宜君',
        'ex[password]': 'ed1617'
    }
)
