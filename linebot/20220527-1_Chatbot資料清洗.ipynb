# %%
'''
開始前，必須先去下載 GCP 為我們搜集的Log
並把名字改為 downloaded-logs.csv
上傳到colab

'''

# %%
'''
讀取csv

python read csv
https://www.shanelynn.ie/python-pandas-read-csv-load-data-from-csv-files/
'''
import pandas as pd 
data = pd.read_csv("downloaded-logs.csv") 
data
# Out:
#    httpRequest.protocol httpRequest.requestMethod  \
# 0              HTTP/1.1                      POST
# 1              HTTP/1.1                      POST
# 2              HTTP/1.1                      POST
# 3              HTTP/1.1                      POST
# 4              HTTP/1.1                      POST
# 5              HTTP/1.1                      POST
# 6              HTTP/1.1                      POST
# 7              HTTP/1.1                      POST
# 8              HTTP/1.1                      POST
# 9              HTTP/1.1                      POST
# 10             HTTP/1.1                      POST
# 11             HTTP/1.1                      POST
# 12             HTTP/1.1                      POST
# 13             HTTP/1.1                      POST
#
#                                httpRequest.requestUrl httpRequest.userAgent  \
# 0   http://rabbit-ai-line-api-test-ud53puwigq-df.a...    LineBotWebhook/2.0
# 1   http://rabbit-ai-line-api-test-ud53puwigq-df.a...    LineBotWebhook/2.0
# 2   http://rabbit-ai-line-api-test-ud53puwigq-df.a...    LineBotWebhook/2.0
# 3   http://rabbit-ai-line-api-test-ud53puwigq-df.a...    LineBotWebhook/2.0
# 4   http://rabbit-ai-line-api-test-ud53puwigq-df.a...    LineBotWebhook/2.0
# 5   http://rabbit-ai-line-api-test-ud53puwigq-df.a...    LineBotWebhook/2.0
# 6   http://rabbit-ai-line-api-test-ud53puwigq-df.a...    LineBotWebhook/2.0
# 7   http://rabbit-ai-line-api-test-ud53puwigq-df.a...    LineBotWebhook/2.0
# 8   http://rabbit-ai-line-api-test-ud53puwigq-df.a...    LineBotWebhook/2.0
# 9   http://rabbit-ai-line-api-test-ud53puwigq-df.a...    LineBotWebhook/2.0
# 10  http://rabbit-ai-line-api-test-ud53puwigq-df.a...    LineBotWebhook/2.0
# 11  http://rabbit-ai-line-api-test-ud53puwigq-df.a...    LineBotWebhook/2.0
# 12  http://rabbit-ai-line-api-test-ud53puwigq-df.a...    LineBotWebhook/2.0
# 13  http://rabbit-ai-line-api-test-ud53puwigq-df.a...    LineBotWebhook/2.0
#
#            insertId            jsonPayload.destination jsonPayload.events  \
# 0    u8t6smg2poyr3m  Ua3f7bc9d856ec7142912b3b917bfa9cb    [object Object]
# 1    gncuuxg4u13bm0  Ua3f7bc9d856ec7142912b3b917bfa9cb    [object Object]
# 2    rhgqqig4vcsvaf  Ua3f7bc9d856ec7142912b3b917bfa9cb    [object Object]
# 3    xl1ij4g4trwre6  Ua3f7bc9d856ec7142912b3b917bfa9cb    [object Object]
# 4   1l5rzujg4sx8amo  Ua3f7bc9d856ec7142912b3b917bfa9cb    [object Object]
# 5    ezpqzig539o9wg  Ua3f7bc9d856ec7142912b3b917bfa9cb    [object Object]
# 6     u8t6smfh2my55  Ua3f7bc9d856ec7142912b3b917bfa9cb    [object Object]
# 7   1l5rzujg4sr1gh5  Ua3f7bc9d856ec7142912b3b917bfa9cb    [object Object]
# 8    svg220g4tgmrq2  Ua3f7bc9d856ec7142912b3b917bfa9cb    [object Object]
# 9    f9z8rlg4urvxlx  Ua3f7bc9d856ec7142912b3b917bfa9cb    [object Object]
# 10   1inv0ulfjayj7s  Ua3f7bc9d856ec7142912b3b917bfa9cb    [object Object]
# 11    u9c4zg52tsg7h  Ua3f7bc9d856ec7142912b3b917bfa9cb    [object Object]
# 12  1j7s2d5g4ubtgit  Ua3f7bc9d856ec7142912b3b917bfa9cb    [object Object]
# 13   jpc5k5g4un8dag  Ua3f7bc9d856ec7142912b3b917bfa9cb    [object Object]
#
#    labels.python_logger                                            logName  \
# 0         ncu_bot_event  projects/rabbit-220516-linebot/logs/ncu_bot_event
# 1         ncu_bot_event  projects/rabbit-220516-linebot/logs/ncu_bot_event
# 2         ncu_bot_event  projects/rabbit-220516-linebot/logs/ncu_bot_event
# 3         ncu_bot_event  projects/rabbit-220516-linebot/logs/ncu_bot_event
# 4         ncu_bot_event  projects/rabbit-220516-linebot/logs/ncu_bot_event
# 5         ncu_bot_event  projects/rabbit-220516-linebot/logs/ncu_bot_event
# 6         ncu_bot_event  projects/rabbit-220516-linebot/logs/ncu_bot_event
# 7         ncu_bot_event  projects/rabbit-220516-linebot/logs/ncu_bot_event
# 8         ncu_bot_event  projects/rabbit-220516-linebot/logs/ncu_bot_event
# 9         ncu_bot_event  projects/rabbit-220516-linebot/logs/ncu_bot_event
# 10        ncu_bot_event  projects/rabbit-220516-linebot/logs/ncu_bot_event
# 11        ncu_bot_event  projects/rabbit-220516-linebot/logs/ncu_bot_event
# 12        ncu_bot_event  projects/rabbit-220516-linebot/logs/ncu_bot_event
# 13        ncu_bot_event  projects/rabbit-220516-linebot/logs/ncu_bot_event
#
#     receiveLocation  ... resource.labels.service_name       resource.type  \
# 0               NaN  ...      rabbit-ai-line-api-test  cloud_run_revision
# 1               NaN  ...      rabbit-ai-line-api-test  cloud_run_revision
# 2               NaN  ...      rabbit-ai-line-api-test  cloud_run_revision
# 3               NaN  ...      rabbit-ai-line-api-test  cloud_run_revision
# 4               NaN  ...      rabbit-ai-line-api-test  cloud_run_revision
# 5               NaN  ...      rabbit-ai-line-api-test  cloud_run_revision
# 6               NaN  ...      rabbit-ai-line-api-test  cloud_run_revision
# 7               NaN  ...      rabbit-ai-line-api-test  cloud_run_revision
# 8               NaN  ...      rabbit-ai-line-api-test  cloud_run_revision
# 9               NaN  ...      rabbit-ai-line-api-test  cloud_run_revision
# 10              NaN  ...      rabbit-ai-line-api-test  cloud_run_revision
# 11              NaN  ...      rabbit-ai-line-api-test  cloud_run_revision
# 12              NaN  ...      rabbit-ai-line-api-test  cloud_run_revision
# 13              NaN  ...      rabbit-ai-line-api-test  cloud_run_revision
#
#    severity sourceLocation.file sourceLocation.function sourceLocation.line  \
# 0      INFO         /app/app.py                callback                  69
# 1      INFO         /app/app.py                callback                  69
# 2      INFO         /app/app.py                callback                  69
# 3      INFO         /app/app.py                callback                  69
# 4      INFO         /app/app.py                callback                  69
# 5      INFO         /app/app.py                callback                  69
# 6      INFO         /app/app.py                callback                  69
# 7      INFO         /app/app.py                callback                  69
# 8      INFO         /app/app.py                callback                  69
# 9      INFO         /app/app.py                callback                  69
# 10     INFO         /app/app.py                callback                  69
# 11     INFO         /app/app.py                callback                  69
# 12     INFO         /app/app.py                callback                  69
# 13     INFO         /app/app.py                callback                  69
#
#               spanId                    timestamp  \
# 0   70ca0f5d38bc1f1d  2022-05-23T02:15:25.441865Z
# 1   ccac8153de682bdc  2022-05-16T08:17:59.835629Z
# 2   4a1385b6fa4e314e  2022-05-16T08:17:51.904852Z
# 3   44cae8d56b1474e6  2022-05-16T08:17:18.427554Z
# 4   6577f712421ed9cb  2022-05-16T06:25:38.076107Z
# 5   5e8414320987514f  2022-05-16T06:25:17.515399Z
# 6   920da89b4821b58c  2022-05-16T06:03:24.251384Z
# 7   ad3b1c282a2a8e12  2022-05-16T06:02:39.565026Z
# 8   8ce01b4b36fba3bb  2022-05-16T06:01:31.584683Z
# 9   dfdd636a51ec912d  2022-05-16T05:59:44.157370Z
# 10  f152be1fb0b44564  2022-05-16T05:59:08.992442Z
# 11  fc20f499632c60b8  2022-05-16T05:58:54.325291Z
# 12  c6884c492a9031aa  2022-05-16T05:58:47.683193Z
# 13  9752a946f0bf5b8a  2022-05-16T05:58:17.412608Z
#
#                                                 trace traceSampled
# 0   projects/rabbit-220516-linebot/traces/486f1760...         True
# 1   projects/rabbit-220516-linebot/traces/45ea7e0f...         True
# 2   projects/rabbit-220516-linebot/traces/cf43ffe6...         True
# 3   projects/rabbit-220516-linebot/traces/8c5f9ec9...         True
# 4   projects/rabbit-220516-linebot/traces/b4753893...         True
# 5   projects/rabbit-220516-linebot/traces/d04d3aac...         True
# 6   projects/rabbit-220516-linebot/traces/30e375c0...         True
# 7   projects/rabbit-220516-linebot/traces/e41c25fc...         True
# 8   projects/rabbit-220516-linebot/traces/d6ae1f72...         True
# 9   projects/rabbit-220516-linebot/traces/15225e45...         True
# 10  projects/rabbit-220516-linebot/traces/fdda5e93...         True
# 11  projects/rabbit-220516-linebot/traces/eff1f38e...          NaN
# 12  projects/rabbit-220516-linebot/traces/5542e26b...         True
# 13  projects/rabbit-220516-linebot/traces/99167b34...         True
#
# [14 rows x 26 columns]

# %%
'''
抓出指定欄位 - jsonPayload.message

'''
data['jsonPayload.message']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'jsonPayload.message'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-b11bcad273b3> in <module>()
#       3
#       4 '''
# ----> 5 data['jsonPayload.message']
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'jsonPayload.message'

# %%
'''
將jsonPayload.message 的欄位內容 轉成csv

欄位若無值，則不填

'''
import json
json_data_list = []


df_message = pd.DataFrame(columns=['userId', 'timestamp', 'event_type','message_type','message_id', 'message_text'])

for row in  data['jsonPayload.message']:
  if json.loads(row).get('events'):
    events = json.loads(row).get('events')[0]
    print(json.loads(row).get('events')[0])
    # json_data_list.append()
    # print(line_event.get('type'))
    # print(line_event.get('message'))
    # print(line_event.get('message').get('id'))
    # print(line_event.get('timestamp'))
    # print(line_event.get('source').get('userId'))
    if events.get('type') not in ['follow','unfollow','postback']:
      df_message = df_message.append(
          {
            'userId': events.get('source').get('userId'), 
            'timestamp': events.get('timestamp'), 
            'event_type': events.get('type'),
            'message_type': events.get('message').get('type'),
            'message_id': events.get('message').get('id'),
            'message_text': events.get('message').get('text')
          },
          ignore_index=True)
    elif events.get('type')  in ['postback']:
      df_message =df_message.append(
          {
            'userId': events.get('source').get('userId'), 
            'timestamp': events.get('timestamp'), 
            'event_type': events.get('type'),
            'message_text': events.get('postback').get('data')
          },
          ignore_index=True
      )
    else:
      df_message = df_message.append(
          {
            'userId': events.get('source').get('userId'), 
            'timestamp': events.get('timestamp'), 
            'event_type': events.get('type')
          },
          ignore_index=True)

df_message

# %%
# 安裝line 套件
# !pip install line-bot-sdk

# %%
'''

設置Line Bot Api 的 Channel access token

'''

from linebot import (
    LineBotApi, WebhookHandler
)

line_bot_api = LineBotApi('CHANNEL_ACCESS_TOKEN')

# %%
'''
取出用戶id，向Line要個資
整理成一份用戶個資名單
'''


user_info_df= pd.DataFrame(columns=['userId', 'display_name', 'picture_url','status_message'])

for user_id in df_message['userId'].unique():
  try:
    line_user_profile = line_bot_api.get_profile(user_id)
    
    user_info_df = user_info_df.append(
        {
          'display_name': line_user_profile.display_name, 
          'userId': line_user_profile.user_id, 
          'picture_url': line_user_profile.picture_url,
          'status_message': line_user_profile.status_message
        },
        ignore_index=True)
  except:
    pass

user_info_df

# %%
'''

將用戶個資名單跟 jsonPayload的欄位內容 整理在一份csv

'''
merge_data = pd.merge(df_message, user_info_df)
merge_data

# %%
'''
timestamp 轉換成人類可懂的時間
'''

import datetime
human_use_date=[]
for stamp in merge_data['timestamp']:
  
  timestamp = datetime.datetime.fromtimestamp(
      stamp/1000+8*3600
      )
  human_use_date.append(timestamp.strftime('%Y-%m-%d %H:%M:%S'))
  

merge_data['human_date']=human_use_date
merge_data

# %%
'''
將資料存成csv
'''
merge_data.to_csv("final_data.csv")

# %%
'''

進行可視化

外國人不考慮中文，中文會是亂碼

'''

# %%
'''
看看誰發的話多
'''

merge_data['userId'].value_counts().sort_index().plot.bar()
# merge_data['timestamp'].plot.hist()

# %%
'''
看看都發哪一類型的消息
'''
merge_data['message_type'].value_counts().sort_index().plot.bar()
